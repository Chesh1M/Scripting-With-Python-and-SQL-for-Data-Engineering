# %% [markdown]
# # Week 1 project:
# - Import a csv file 'wine-ratings.csv', filtering out rows based on data specified
# - Save selected rows to a new JSON file

# %% [markdown]
# **Import pandas and initialize dataframe**

# %%
import pandas as pd
df = pd.read_csv(r"./wine-ratings.csv", index_col=0)

df.head()
# Out:
#                                                 name  grape  \
# 0  1000 Stories Bourbon Barrel Aged Batch Blue Ca...    NaN
# 1  1000 Stories Bourbon Barrel Aged Gold Rush Red...    NaN
# 2  1000 Stories Bourbon Barrel Aged Gold Rush Red...    NaN
# 3    1000 Stories Bourbon Barrel Aged Zinfandel 2013    NaN
# 4    1000 Stories Bourbon Barrel Aged Zinfandel 2014    NaN
#
#                     region   variety  rating  \
# 0    Mendocino, California  Red Wine    91.0
# 1               California  Red Wine    89.0
# 2               California  Red Wine    90.0
# 3  North Coast, California  Red Wine    91.0
# 4               California  Red Wine    90.0
#
#                                                notes
# 0  This is a very special, limited release of 100...
# 1  The California Gold Rush was a period of coura...
# 2  The California Gold Rush was a period of coura...
# 3  The wine has a deep, rich purple color. An int...
# 4  Batch #004 is the first release of the 2014 vi...

# %% [markdown]
# **Get rid of 'grape' column since it's empty**

# %%
df.drop('grape', axis='columns', inplace=True)
df.head()
# Out:
#                                                 name                   region  \
# 0  1000 Stories Bourbon Barrel Aged Batch Blue Ca...    Mendocino, California
# 1  1000 Stories Bourbon Barrel Aged Gold Rush Red...               California
# 2  1000 Stories Bourbon Barrel Aged Gold Rush Red...               California
# 3    1000 Stories Bourbon Barrel Aged Zinfandel 2013  North Coast, California
# 4    1000 Stories Bourbon Barrel Aged Zinfandel 2014               California
#
#     variety  rating                                              notes
# 0  Red Wine    91.0  This is a very special, limited release of 100...
# 1  Red Wine    89.0  The California Gold Rush was a period of coura...
# 2  Red Wine    90.0  The California Gold Rush was a period of coura...
# 3  Red Wine    91.0  The wine has a deep, rich purple color. An int...
# 4  Red Wine    90.0  Batch #004 is the first release of the 2014 vi...

# %% [markdown]
# **Filter data by**
# 1) variety - White Wine
# 2) rating >= 90
# 3) region - France, Italy

# %% [markdown]
# **Filter by white wines only**

# %%
df = df.loc[df['variety'] == 'White Wine']
df.head()
# Out:
#                                          name      region     variety  rating  \
# 12                   14 Hands Chardonnay 2011  Washington  White Wine    89.0
# 16                     14 Hands Riesling 2014  Washington  White Wine    88.0
# 17                     14 Hands Riesling 2015  Washington  White Wine    88.0
# 18                     14 Hands Riesling 2016  Washington  White Wine    88.0
# 26  1865 Single Vineyard Sauvignon Blanc 2011       Chile  White Wine    91.0
#
#                                                 notes
# 12  This Chardonnay displays aromas and flavors of...
# 16  This crisp Riesling shows bright flavors of ap...
# 17  This crisp Riesling shows bright flavors of ap...
# 18  This crisp Riesling shows bright flavors of ap...
# 26  Almost transparent pale yellow, young, with gr...

# %% [markdown]
# **Filter by ratings >= 90**

# %%
df = df.loc[df['rating'] >= 90]
df.head()
# Out:
#                                          name  \
# 26  1865 Single Vineyard Sauvignon Blanc 2011
# 27  1865 Single Vineyard Sauvignon Blanc 2013
# 28  1865 Single Vineyard Sauvignon Blanc 2014
# 29  1865 Single Vineyard Sauvignon Blanc 2015
# 44              3 Stones Sauvignon Blanc 2008
#
#                                              region     variety  rating  \
# 26                                            Chile  White Wine    91.0
# 27                                            Chile  White Wine    90.0
# 28  Leyda Valley, San Antonio Valley (Chile), Chile  White Wine    90.0
# 29  Leyda Valley, San Antonio Valley (Chile), Chile  White Wine    91.0
# 44                         Marlborough, New Zealand  White Wine    90.0
#
#                                                 notes
# 26  Almost transparent pale yellow, young, with gr...
# 27  A brilliant, pale, almost transparent yellow w...
# 28  A brilliant, pale, almost transparent yellow w...
# 29  A brilliant, pale, almost transparent yellow w...
# 44  3 Stones is New Zealand wine emblazoned with a...

# %% [markdown]
# **Filer by region from either France or Italy**
#
# Since the regions are not straightforward/direct we look for partial strings

# %%
df = df.loc[df['region'].str.contains('Italy|France')]
df
# Out:
#                                                     name  \
# 173             Abbazia di Novacella Gewurztraminer 2007
# 174           Abbazia di Novacella Gruner Veltliner 2017
# 175                     Abbazia di Novacella Kerner 2007
# 176                     Abbazia di Novacella Kerner 2016
# 177                     Abbazia di Novacella Kerner 2017
# ...                                                  ...
# 32575      Leone de Castris Verdeca Bianco Messapia 2009
# 32654                       Les Cretes Les Abeilles 2006
# 32655           Les Cretes Valle d'Aosta Chardonnay 2010
# 32656  Les Cretes Valle d'Aosta Cuvee Bois Chardonnay...
# 32668           Les Hauts de Lagarde Bordeaux Blanc 2013
#
#                                        region     variety  rating  \
# 173                Trentino-Alto Adige, Italy  White Wine    90.0
# 174    Alto Adige, Trentino-Alto Adige, Italy  White Wine    90.0
# 175                Trentino-Alto Adige, Italy  White Wine    91.0
# 176                Trentino-Alto Adige, Italy  White Wine    91.0
# 177                Trentino-Alto Adige, Italy  White Wine    94.0
# ...                                       ...         ...     ...
# 32575                                   Italy  White Wine    90.0
# 32654                    Valle d'Aosta, Italy  White Wine    91.0
# 32655                                   Italy  White Wine    92.0
# 32656                    Valle d'Aosta, Italy  White Wine    94.0
# 32668                        Bordeaux, France  White Wine    91.0
#
#                                                    notes
# 173    Typical white wine, elegant and aromatic, ligh...
# 174    This wine offers fresh green apple aromas and ...
# 175    The color goes from pale straw yellow with gre...
# 176    An aromatic white wine, which has become a spe...
# 177    100% Kerner from gravelly marine soils planted...
# ...                                                  ...
# 32575  Made from 100% Verdeca, an ancient Greek varie...
# 32654  Brilliant golden yellow hue. Fruit (dried apri...
# 32655  Valle d'Aosta Chardonnay is a lovely yellow. T...
# 32656  The opening to the nose ranges from banana to ...
# 32668                                                NaN
#
# [1690 rows x 5 columns]

# %% [markdown]
# **Reset index of the dataframe**

# %%
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#                                          name  \
# 0    Abbazia di Novacella Gewurztraminer 2007
# 1  Abbazia di Novacella Gruner Veltliner 2017
# 2            Abbazia di Novacella Kerner 2007
# 3            Abbazia di Novacella Kerner 2016
# 4            Abbazia di Novacella Kerner 2017
#
#                                    region     variety  rating  \
# 0              Trentino-Alto Adige, Italy  White Wine    90.0
# 1  Alto Adige, Trentino-Alto Adige, Italy  White Wine    90.0
# 2              Trentino-Alto Adige, Italy  White Wine    91.0
# 3              Trentino-Alto Adige, Italy  White Wine    91.0
# 4              Trentino-Alto Adige, Italy  White Wine    94.0
#
#                                                notes
# 0  Typical white wine, elegant and aromatic, ligh...
# 1  This wine offers fresh green apple aromas and ...
# 2  The color goes from pale straw yellow with gre...
# 3  An aromatic white wine, which has become a spe...
# 4  100% Kerner from gravelly marine soils planted...

# %% [markdown]
# **Convert df to formatted json**
#
# Other formatting options (orient values)
# - 'split’, ‘records’, ‘index’, ‘columns’, ‘values’

# %%
df.to_json('filtered-wine-ratings.json', orient='index', indent=4)
